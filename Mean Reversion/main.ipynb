# %%
import MeanReversion as mr

# %%
m_rev = mr.mean_reversion_bt('MSFT', '2018-12-31')

print('------   RESULTS   -----')
print(f'Strategy: {round(m_rev.cum_profit,4)*100}%\nBuy/hold: {round(m_rev.buyHold,4)*100}%\nDifference: {round(m_rev.cum_profit-m_rev.buyHold,4)*100}%\n')

m_rev.current_signal()
#m_rev.trade_breakdown()
# Out:
# [*********************100%***********************]  1 of 1 completed
# ------   RESULTS   -----
# Strategy: 15.64%
# Buy/hold: 180.06%
# Difference: -164.42000000000002%
#
# Current signal as of 2023-03-28 00:00:00:
#
# 0

# %%
m_rev.plot_bands()

# %%
m_rev.df.tail(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-03-15  259.980011  266.480011  259.209991  265.440002  265.440002
# 2023-03-16  265.209991  276.559998  263.279999  276.200012  276.200012
# 2023-03-17  278.260010  283.329987  276.320007  279.429993  279.429993
# 2023-03-20  276.980011  277.480011  269.850006  272.230011  272.230011
# 2023-03-21  274.880005  275.000000  269.519989  273.779999  273.779999
# 2023-03-22  273.399994  281.040009  272.179993  272.290009  272.290009
# 2023-03-23  277.940002  281.059998  275.200012  277.660004  277.660004
# 2023-03-24  277.239990  280.630005  275.279999  280.570007  280.570007
# 2023-03-27  280.500000  281.459991  275.519989  276.380005  276.380005
# 2023-03-28  280.500000  276.130005  275.375000  275.500000  275.500000
#
#               Volume    HighBand  MiddleBand     LowBand        rsi  \
# Date
# 2023-03-15  46028000  268.194594  255.243241  242.291888  73.843457
# ...
